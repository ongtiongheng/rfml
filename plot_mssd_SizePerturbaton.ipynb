# %% [markdown]
# <a href="https://colab.research.google.com/github/ongtiongheng/rfml/blob/master/plot_mssd_SizePerturbaton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#var = pd.read_excel("/tmp/MSSD-combined-data-swap-only.xlsx",header=0,converters={'Attack-SNR(DB)':str)
#print(var)

#df = pd.DataFrame(var, columns= ['Attack-SNR(DB)',"1",'4','8','12','16'])
#df = pd.read_excel('Book1.xlsx',sheetname='Sheet1',header=0,converters={'names':str,'ages':str})

index = ['1','4','8','12','16']

df = pd.DataFrame([
	  [10,36,2,29,1,9,12,0],
    [7,32,5,27,1,5,35,0],
    [5,31,12,39,1,3,53,4],
    [8,35,22,69,0,3,70,43],
    [12,43,40,84,1,11,82,85]],
    columns=['FGSM-CLDNN-BPSK','FGSM-CLDNN-PAM4','FGSM-VTCNN2-BPSK','FGSM-VTCNN2-PAM4','FGSM-VTCNN2-QAM16','FGSM-VTCNN2-QAM64','FGSM-VTCNN2-GFSK', 'FGSM-VTCNN2-CPFSK'], index=index
)

#ax = plt.gca()

#plt.rcParams["figure.figsize"] = [30, 10]
#plt.xticks(rotation = 45) # Rotates X-Axis Ticks by 45-degrees
plt.style.use('seaborn-white')
#plt.xticks(list(range(len(index))), df.index, fontsize=11)
df.plot(figsize=(10,5),grid=True,title='Size of Perturbation and Accuracy (a)',marker='o')
file_path = "/tmp/SizeofPerturbationandAccuracy-FGSM.svg"
plt.savefig(file_path, format="svg")
plt.xlabel('Perturbation')
plt.ylabel('Accuracy')
plt.show()
#plt.xticks(ticks=x_ticks)
#plt.show()

# plotting a bar graph
# Draw a scatter plot
#df.plot.scatter(x = 'Attack-SNR(DB)', y = '1');
#df.plot(kind='scatter',x='num_children',y='num_pets',color='red')
#df.plot(x="Attack-SNR(DB)", y="1", kind="bar")
#np_plot = np.array(var)

#plt.plot(np_plot)
#plt.title('title name')
#plt.xlabel('xAxis name')
#plt.ylabel('yAxis name')
#plt.show()
