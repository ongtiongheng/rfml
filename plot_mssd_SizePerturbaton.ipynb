# %% [markdown]
# <a href="https://colab.research.google.com/github/ongtiongheng/rfml/blob/master/plot_mssd_SizePerturbaton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#var = pd.read_excel("/tmp/MSSD-combined-data-swap-only.xlsx",header=0,converters={'Attack-SNR(DB)':str)
#print(var)

#df = pd.DataFrame(var, columns= ['Attack-SNR(DB)',"1",'4','8','12','16'])
#df = pd.read_excel('Book1.xlsx',sheetname='Sheet1',header=0,converters={'names':str,'ages':str})

index = ['1','4','8','12','16']

df = pd.DataFrame([
    [10,36,3,0,2,29,1,9,3,1,12,0,1,0,0,2,3,0,0,3,0],
    [7,32,1,1,5,27,1,5,3,3,35,0,12,1,3,0,0,0,0,12,0],
    [5,31,1,1,12,39,1,3,1,4,53,4,34,11,12,0,1,0,0,38,1],
    [8,35,1,1,22,69,0,3,3,5,70,43,53,24,53,0,7,1,0,65,14],
    [12,43,1,0,40,84,1,11,10,20,82,85,72,52,86,3,25,13,7,82,62]],
    columns=['FGSM-CLDNN-BPSK','FGSM-CLDNN-PAM4','FGSM-CLDNN-GFSK','FGSM-CLDNN-CPFSK','FGSM-VTCNN2-BPSK','FGSM-VTCNN2-PAM4','FGSM-VTCNN2-QAM16','FGSM-VTCNN2-QAM64','FGSM-VTCNN2-8PSK','FGSM-VTCNN2-QPSK','FGSM-VTCNN2-GFSK','FGSM-VTCNN2-CPFSK','PGD-CLDNN-BPSK','PGD-VTCNN2-BPSK','PGD-VTCNN2-PAM4','PGD-VTCNN2-QAM16','PGD-VTCNN2-QAM64','PGD-VTCNN2-8PSK','PGD-VTCNN2-QPSK','PGD-VTCNN2-GFSK','PGD-VTCNN2-CPFSK'], index=index
)

#ax = plt.gca()

#plt.rcParams["figure.figsize"] = [30, 10]
#plt.xticks(rotation = 45) # Rotates X-Axis Ticks by 45-degrees
plt.style.use('seaborn-white')
#plt.xticks(list(range(len(index))), df.index, fontsize=11)
df.plot(figsize=(30,10),grid=True,title='Size of Perturbation and Accuracy',marker='o')
file_path = "/tmp/SizeofPerturbationandAccuracy.svg"
plt.savefig(file_path, format="svg")
plt.show()
#plt.xticks(ticks=x_ticks)
#plt.show()

# plotting a bar graph
# Draw a scatter plot
#df.plot.scatter(x = 'Attack-SNR(DB)', y = '1');
#df.plot(kind='scatter',x='num_children',y='num_pets',color='red')
#df.plot(x="Attack-SNR(DB)", y="1", kind="bar")
#np_plot = np.array(var)

#plt.plot(np_plot)
#plt.title('title name')
#plt.xlabel('xAxis name')
#plt.ylabel('yAxis name')
#plt.show()
