# %% [markdown]
# <a href="https://colab.research.google.com/github/ongtiongheng/rfml/blob/master/plot_mssd_SizePerturbaton_PGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#var = pd.read_excel("/tmp/MSSD-combined-data-swap-only.xlsx",header=0,converters={'Attack-SNR(DB)':str)
#print(var)

#df = pd.DataFrame(var, columns= ['Attack-SNR(DB)',"1",'4','8','12','16'])
#df = pd.read_excel('Book1.xlsx',sheetname='Sheet1',header=0,converters={'names':str,'ages':str})

index = ['1','4','8','12','16']

df = pd.DataFrame([
    [1,0,0,2,3,0,0,3,0],
    [12,1,3,0,0,0,0,12,0],
    [34,11,12,0,1,0,0,38,1],
    [53,24,53,0,7,1,0,65,14],
    [72,52,86,3,25,13,7,82,62]],
    columns=['AT-PGD-CLDNN-BPSK','AT-PGD-VTCNN2-BPSK','AT-PGD-VTCNN2-PAM4','AT-PGD-VTCNN2-QAM16','AT-PGD-VTCNN2-QAM64','AT-PGD-VTCNN2-8PSK','AT-PGD-VTCNN2-QPSK','AT-PGD-VTCNN2-GFSK','AT-PGD-VTCNN2-CPFSK'], index=index
)
#ax = plt.gca()

#plt.rcParams["figure.figsize"] = [30, 10]
#plt.xticks(rotation = 45) # Rotates X-Axis Ticks by 45-degrees
#plt.style.use('seaborn-white')
#plt.xticks(list(range(len(index))), df.index, fontsize=11)
df.plot(figsize=(10,5),grid=True,title='Size of Perturbation and Accuracy (b)',marker='o')
file_path = "/tmp/SizeofPerturbationandAccuracy-PGD.svg"
plt.xlabel('Perturbation')
plt.ylabel('Accuracy')
plt.savefig(file_path, format="svg")
#plt.show()
#plt.xticks(ticks=x_ticks)
#plt.show()

# plotting a bar graph
# Draw a scatter plot
#df.plot.scatter(x = 'Attack-SNR(DB)', y = '1');
#df.plot(kind='scatter',x='num_children',y='num_pets',color='red')
#df.plot(x="Attack-SNR(DB)", y="1", kind="bar")
#np_plot = np.array(var)

#plt.plot(np_plot)
#plt.title('title name')
#plt.xlabel('xAxis name')
#plt.ylabel('yAxis name')
#plt.show()
